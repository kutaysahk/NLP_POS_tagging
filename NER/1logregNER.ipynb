# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
def load_data(file_path):
    tokens = []
    labels = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line:
                parts = line.split()
                if len(parts) >= 2:
                    tokens.append(parts[0])
                    labels.append(parts[1])
    return tokens, labels

# %%
train_tokens, train_labels = load_data('train_corrected.txt')
test_tokens, test_labels = load_data('test_corrected.txt')

vectorizer = TfidfVectorizer(lowercase=False, token_pattern=r"\S+")
X_train = vectorizer.fit_transform(train_tokens)
X_test = vectorizer.transform(test_tokens)

# %%
print("Training Logistic Regression...")
lr = LogisticRegression(max_iter=1000, solver='saga', n_jobs=-1)
lr.fit(X_train, train_labels)

print("Predicting...")
predictions = lr.predict(X_test)
unique_labels = sorted(list(set(test_labels)))
# Out:
# Training Logistic Regression...
#
# Predicting...

# %%
print(f"Accuracy Score: {accuracy_score(test_labels, predictions) * 100:.2f}%")
print(classification_report(test_labels, predictions, digits=4, zero_division=0))
# Out:
# Accuracy Score: 82.30%
#               precision    recall  f1-score   support
#
#        B-CRD     0.5242    0.3449    0.4161      1006
#        B-DAT     0.8069    0.7741    0.7902       788
#        B-EVT     0.7153    0.5659    0.6319       182
#        B-FAC     0.4667    0.2258    0.3043        93
#        B-GPE     0.5693    0.6955    0.6261      1376
#        B-LAW     0.5625    0.2571    0.3529        35
#        B-LOC     0.5025    0.3414    0.4066       290
#        B-MON     0.9259    0.7843    0.8493       255
#        B-NOR     0.7330    0.6202    0.6719       903
#        B-ORD     0.8000    0.5390    0.6441       141
#        B-ORG     0.6532    0.5094    0.5724       854
#        B-PER     0.7316    0.3506    0.4741      1446
#        B-PRC     0.5532    0.2708    0.3636       192
#        B-PRD     0.7259    0.4332    0.5426       868
#        B-QTY     0.1515    0.0185    0.0329       271
#        B-REG     0.7429    0.5778    0.6500        45
# ...
