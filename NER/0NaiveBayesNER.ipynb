# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
def load_data(file_path):
    tokens = []
    labels = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line:
                parts = line.split()
                if len(parts) >= 2:
                    tokens.append(parts[0])
                    labels.append(parts[1])
    return tokens, labels

# %%
train_tokens, train_labels = load_data('train_corrected.txt')
test_tokens, test_labels = load_data('test_corrected.txt')

vectorizer = CountVectorizer(lowercase=False, token_pattern=r"\S+")
X_train = vectorizer.fit_transform(train_tokens)
X_test = vectorizer.transform(test_tokens)

# %%
nb = MultinomialNB()
nb.fit(X_train, train_labels)

predictions = nb.predict(X_test)
unique_labels = sorted(list(set(test_labels)))

# %%
acc=accuracy_score(test_labels, predictions)
print(f"Accuracy: {acc:.4f}%")
print(classification_report(test_labels, predictions, digits=4, zero_division=0))
# Out:
# Accuracy: 0.8066%
#               precision    recall  f1-score   support
#
#        B-CRD     0.4966    0.2913    0.3672      1006
#        B-DAT     0.9103    0.5279    0.6683       788
#        B-EVT     0.8033    0.2692    0.4033       182
#        B-FAC     0.0000    0.0000    0.0000        93
#        B-GPE     0.5682    0.7173    0.6341      1376
#        B-LAW     0.0000    0.0000    0.0000        35
#        B-LOC     0.6038    0.1103    0.1866       290
#        B-MON     0.9553    0.6706    0.7880       255
#        B-NOR     0.7364    0.3588    0.4825       903
#        B-ORD     0.0000    0.0000    0.0000       141
#        B-ORG     0.6926    0.4590    0.5521       854
#        B-PER     0.7594    0.3209    0.4511      1446
#        B-PRC     0.0000    0.0000    0.0000       192
#        B-PRD     0.7938    0.2661    0.3986       868
#        B-QTY     0.0000    0.0000    0.0000       271
#        B-REG     0.0000    0.0000    0.0000        45
#        B-TIM     0.0000    0.0000    0.0000       118
#        B-WOA     0.0000    0.0000    0.0000         2
#        I-CRD     0.0000    0.0000    0.0000       354
#        I-DAT     0.4842    0.6963    0.5712      1887
#        I-EVT     0.5000    0.0426    0.0786       258
#        I-FAC     0.0000    0.0000    0.0000       146
#        I-GPE     0.6286    0.2797    0.3871       472
#        I-LAW     1.0000    0.0841    0.1552       107
#        I-LOC     0.2791    0.0829    0.1279       434
#        I-MON     0.5455    0.2857    0.3750       525
#        I-NOR     0.5627    0.2713    0.3661      1257
#        I-ORG     0.4275    0.1276    0.1966       901
#        I-PER     0.6995    0.1130    0.1945      1133
#        I-PRC     0.9793    0.4785    0.6429       395
#        I-PRD     0.6604    0.0452    0.0846       774
#        I-QTY     0.8667    0.0357    0.0686       364
#        I-REG     0.0000    0.0000    0.0000        35
#        I-TIM     0.7987    0.3742    0.5096       318
#        I-WOA     0.0000    0.0000    0.0000         5
#            O     0.8424    0.9954    0.9126     46339
#
#     accuracy                         0.8066     64569
#    macro avg     0.4609    0.2196    0.2667     64569
# weighted avg     0.7720    0.8066    0.7620     64569
